# %% [markdown]
# English_Malayalam_Multimodal_Machine_Translation

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.image as mp

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Training data preprocessing

# %%
#Vocab extra
engtxt = []
teltxt = []

with open('/content/drive/My Drive/engtel.txt') as file:
    for line in file:
        parts = line.split("++++$++++")
        if len(parts) == 2:
            engtxt.append(parts[0].strip())
            teltxt.append(parts[1].strip())

# %%
with open('/content/drive/My Drive/train/teltrain.txt') as file:
    train_mal_txt = file.read().split('\n')
with open('/content/drive/My Drive/train/engtrain.txt') as file:
    train_eng_txt = file.read().split('\n')
with open('/content/drive/My Drive/train/trainimages.txt') as file:
   train_images = file.read().split('\n')

# %%
print(len(train_mal_txt))
print(len(train_eng_txt))
# Out:
# 28930
# 28929

# %%
train_mal_txt.pop()
# Out:
# ''

# %%
print(len(train_mal_txt))
print(len(train_eng_txt))
# Out:
# 28929
# 28929

# %%
print(train_mal_txt[-1])
print(train_eng_txt[-1])
# Out:
# రైలు యొక్క ఎడమ టెయిల్ లైట్
# a train's left tail light

# %%
#Datacleaning by removing special characters
import re
def clean_text(text):
    text = text.lower()
    text = re.sub(r" ᠃", "", text)
    text = re.sub(r" ᠂", "", text)
    text = re.sub(r"-", " ", text)
    text = re.sub(r"<5>", "5", text)
    text = re.sub(r"“ ", "", text)
    text = re.sub(r" ”", "", text)
    text = re.sub(r"[+\.\!\/_,$%^*(+\"\']+|[+——！，〈〉《》。︱？?、．％~@#￥%……&*（）’]", "", text)
    text=text.rstrip()
    return text

# %%
with open('/content/drive/My Drive/test/teltest.txt') as file:
    test_tel_txt = file.read().split('\n')
with open('/content/drive/My Drive/test/engtest.txt') as file:
    test_eng_txt = file.read().split('\n')
with open('/content/drive/My Drive/test/testimages.txt') as file:
   test_images = file.read().split('\n')

# %%
def remove(mal_txt,eng_txt):
        mal_txt.pop()
        eng_txt.pop()
        eng_txt.pop()
        #trainimages.pop()
        #trainimages,link
        print(len(mal_txt))
        print(len(eng_txt))
        #print(len(trainimages))
        #img_path=[]
        #for s in trainimages:
                 #img_path.append(link+s)
        #return mal_txt,eng_txt,train_images,img_path
        return mal_txt,eng_txt

# %%
trmal_df = pd.DataFrame(train_mal_txt, columns=['Malayalam'])
treng_df = pd.DataFrame(train_eng_txt, columns=['English'])

# %%
trmal_text1 = trmal_df["Malayalam"].apply(clean_text)
treng_text1 = treng_df["English"].apply(clean_text)
trmal_text2 = list(trmal_text1.values)
treng_text2 = list(treng_text1.values)

# %%
trmal_temp=[]
for s in trmal_text2:
    trtemp="sos "+s+" eos"
    trmal_temp.append(trtemp)
#text2=[]
trmal_text2=trmal_temp
trmal_text2[1:10]
# Out:
# ['sos కంప్యూటర్ స్క్రీన్\u200cలు ఆన్ చేయబడ్డాయి eos',
#  'sos మనిషికి చిన్న జుట్టు ఉంది eos',
#  'sos పెద్దల ఒడిలో తెరిచిన ఫోటో ఆల్బమ్ eos',
#  'sos నల్ల కారు పక్కన అమ్మాయిల గుంపు ఉంది eos',
#  'sos స్త్రోలర్\u200cలో ఉన్న పిల్లవాడు eos',
#  'sos పొడవైన మెటల్ లైట్\u200cపోస్ట్ eos',
#  'sos గోడ తెల్లగా పెయింట్ చేయబడింది eos',
#  'sos గోడపై అనేక చిత్రాలు ఉన్నాయి eos',
#  'sos సముద్రానికి ఎదురుగా ఉన్న స్త్రీ eos']

# %%
import seaborn as sn
import matplotlib.pyplot as plt
trmalayalam_words = []
for i in trmal_text2:
    trmalayalam_words.append(len(i.split()))
# sn.countplot(trmalayalam_words).set(title=' Sentence Length -Telugu')
# plt.show()

# %%
trenglish_words = []
for j in treng_text2:
    trenglish_words.append(len(j.split()))
# sn.countplot(trenglish_words).set(title=' Sentence Length -English')
# plt.show()

# %%
trmaxlen_malayalam = max(trmalayalam_words)
trmaxlen_english = max(trenglish_words)
print('Maximum sentence length-Telugu :',trmaxlen_malayalam)
print('Maximum sentence length-English :',trmaxlen_english)
# Out:
# Maximum sentence length-Telugu : 21
# Maximum sentence length-English : 25

# %% [markdown]
# Validation Data Preprocessing

# %%
with open('/content/drive/My Drive/dev/teldev.txt') as file:
    dev_mal_txt = file.read().split('\n')
with open('/content/drive/My Drive/dev/engdev.txt') as file:
    dev_eng_txt = file.read().split('\n')
with open('/content/drive/My Drive/dev/devimages.txt') as file:
   dev_images = file.read().split('\n')

# %%
print(len(dev_mal_txt))
print(len(dev_eng_txt))
# Out:
# 998
# 999

# %%
print(dev_mal_txt[-2])
print(dev_eng_txt[-2])
# Out:
# టెన్నిస్ ఆడుతున్న వ్యక్తి
# blue colored SUV

# %%
dev_eng_txt.pop()
# Out:
# ''

# %%
print(len(dev_mal_txt))
print(len(dev_eng_txt))
# Out:
# 998
# 998

# %%
dmal_df = pd.DataFrame(dev_mal_txt, columns=['Malayalam'])
deng_df = pd.DataFrame(dev_eng_txt, columns=['English'])

# %%
dmal_text1 = dmal_df["Malayalam"].apply(clean_text)
deng_text1 = deng_df["English"].apply(clean_text)
dmal_text2 = list(dmal_text1.values)
deng_text2 = list(deng_text1.values)

# %%
dmal_temp=[]
for s in dmal_text2:
    dtemp="sos "+s+" eos"
    dmal_temp.append(dtemp)
#text2=[]
dmal_text2=dmal_temp
dmal_text2[1:10]
# Out:
# ['sos చాలా మాంసంతో కూడిన శాండ్\u200cవిచ్ వస్తువుల ముక్క eos',
#  'sos పార్క్ దృశ్యం యొక్క నలుపు మరియు తెలుపు చిత్రం eos',
#  'sos సింక్ మీద పెద్ద దీర్ఘచతురస్రాకార అద్దం eos',
#  'sos విమానంలో ఆహారాన్ని లోడ్ చేస్తున్న కారు eos',
#  'sos నేల పలకలతో తయారు చేయబడింది eos',
#  'sos స్కేట్\u200cబోర్డ్\u200cపై ఉన్న యువకుడు eos',
#  'sos అవుట్\u200cడోర్ బ్లూ మెయిల్\u200cబాక్స్ రిసెప్టాకిల్ eos',
#  'sos సన్ గ్లాసెస్\u200cతో సెల్\u200cఫోన్ పట్టుకున్న మహిళ eos',
#  'sos పిల్లి eos']

# %%
import seaborn as sn
import matplotlib.pyplot as plt
dmalayalam_words = []
for i in dmal_text2:
    dmalayalam_words.append(len(i.split()))
# sn.countplot(dmalayalam_words).set(title=' Sentence Length -Malayalam')
# plt.show()

# %%
denglish_words = []
for j in deng_text2:
    denglish_words.append(len(j.split()))
# sn.countplot(denglish_words).set(title=' Sentence Length -English')
# plt.show()

# %%
dmaxlen_malayalam = max(dmalayalam_words)
dmaxlen_english = max(denglish_words)
print('Maximum sentence length-Telugu :',dmaxlen_malayalam)
print('Maximum sentence length-English :',dmaxlen_english)
# Out:
# Maximum sentence length-Telugu : 11
# Maximum sentence length-English : 13

# %% [markdown]
# Test data preprocessing

# %%
with open('/content/drive/My Drive/test/teltest.txt') as file:
    test_mal_txt = file.read().split('\n')
with open('/content/drive/My Drive/test/engtest.txt') as file:
    test_eng_txt = file.read().split('\n')
with open('/content/drive/My Drive/test/testimages.txt') as file:
   test_images = file.read().split('\n')

# %%
print(len(test_mal_txt))
print(len(test_eng_txt))
# Out:
# 1596
# 1595

# %%
test_mal_txt[-2]
# Out:
# 'ఒక పక్షి వాతావరణ వ్యాన్'

# %%
test_eng_txt[-2]
# Out:
# 'green broccoli with chicken\t   '

# %%
test_mal_txt.pop()
test_eng_txt.pop()
# Out:
# 'a bird weather vane\t   '

# %%
print(len(test_mal_txt))
print(len(test_eng_txt))
# Out:
# 1595
# 1594

# %%
ttmal_df = pd.DataFrame(test_mal_txt, columns=['Malayalam'])
tteng_df = pd.DataFrame(test_eng_txt, columns=['English'])

# %%
ttmal_text1 = ttmal_df["Malayalam"].apply(clean_text)
tteng_text1 = tteng_df["English"].apply(clean_text)
ttmal_text2 = list(ttmal_text1.values)
tteng_text2 = list(tteng_text1.values)

# %%
ttmal_temp=[]
for s in ttmal_text2:
    tttemp="sos "+s+" eos"
    ttmal_temp.append(tttemp)
#text2=[]
ttmal_text2=ttmal_temp
ttmal_text2[1:10]
# Out:
# ['sos ఒక స్టాప్ లైట్ eos',
#  'sos అడవిలో మూడు జీబ్రాలు eos',
#  'sos రోడ్డు పక్కన పార్క్ చేసిన కార్లు eos',
#  'sos ఒక వ్యక్తి రైలులోకి ఎక్కుతున్నాడు eos',
#  'sos ఇది ఒక వ్యక్తి eos',
#  'sos ఒక పెట్టెలో చిన్న నారింజల పెట్టె eos',
#  'sos పోస్ట్\u200cలో ట్రామ్\u200cల గురించి సంకేతాలు eos',
#  'sos డోనట్స్\u200cతో నిండిన తెల్లటి పెట్టె eos',
#  'sos నల్ల టోపీ ధరించిన వ్యక్తి eos']

# %%
import seaborn as sn
import matplotlib.pyplot as plt
ttmalayalam_words = []
for i in ttmal_text2:
    ttmalayalam_words.append(len(i.split()))
sn.countplot(ttmalayalam_words).set(title=' Sentence Length -Malayalam')
plt.show()

# %%
ttenglish_words = []
for j in tteng_text2:
    ttenglish_words.append(len(j.split()))
sn.countplot(ttenglish_words).set(title=' Sentence Length -English')
plt.show()

# %%
ttmaxlen_malayalam = max(ttmalayalam_words)
ttmaxlen_english = max(ttenglish_words)
print('Maximum sentence length-Malayalam :',ttmaxlen_malayalam)
print('Maximum sentence length-English :',ttmaxlen_english)
# Out:
# Maximum sentence length-Malayalam : 13
# Maximum sentence length-English : 12

# %%
x_tt=tteng_text2
y_tt=ttmal_text2

# %% [markdown]
# Tokenizing

# %%
x_tr=treng_text2

y_tr=trmal_text2

x_val=deng_text2

y_val=dmal_text2

# %%
#Tokening the sentences using Keras tokenizer -Malayalam data
from keras.preprocessing.text import Tokenizer
x_tokens = Tokenizer()
x_tokens.fit_on_texts(x_tr)
x_tr = x_tokens.texts_to_sequences(x_tr)
x_val = x_tokens.texts_to_sequences(x_val)
print('x_tr:',x_tr)
print(len(x_tokens.word_index))
print('x_val:',x_val)
# Out:
# x_tr: [[145, 5, 29, 2227, 252], [146, 1862, 506, 3], [8, 51, 245, 79], [166, 2228, 168, 3, 29, 2978, 689], [237, 5, 1, 135, 4, 418, 449, 2, 10, 59], [157, 6, 1, 979], [118, 109, 2979], [25, 5, 310, 7], [237, 27, 336, 808, 3, 2, 25], [15, 496, 2, 174], [14, 5, 29, 753, 2980], [212, 1036, 439], [2981, 5, 3, 1, 30], [1, 7, 352, 345], [7, 690, 346, 262, 717], [18, 440, 33, 11, 83], [8, 6, 96, 230, 347, 3, 28], [50, 3, 2, 28], [1, 8, 32, 6, 615, 410], [450, 121, 3, 25], [320, 4, 2, 133], [50, 4, 1, 95], [2, 441, 5, 170], [1, 8, 582, 1, 365], [1, 18, 886, 6, 26], [208, 11, 843, 468], [258, 3, 2, 44], [1, 546, 7, 44], [10, 214, 516], [1, 18, 1279, 595, 6, 2, 291, 4, 2, 59], [16, 59, 91, 474, 1, 33], [59, 3, 2, 33], [1419, 1420, 20, 2982], [1, 10, 59, 11, 1, 21, 161], [133, 52, 2, 30], [1, 2229, 53, 3, 1, 241], [85, 337, 4, 1, 28], [50, 3, 1, 28], [17, 30, 32, 3, 60, 4, 1, 108], [108, 208, 5, 3], [1, 21, 41], [424, 4, 2, 76], [664, 70, 181, 2, 28], [844, 10, 92, 11, 1, 7, 451], [1, 88, 225, 70], [1, 200], [8, 51, 17, 79], [48, 6, 1, 68], [1, 34, 17, 76, 291], [71, 59, 6, 73, 4, 1, 28], [8, 547, 52, 241], [15, 32, 52, 1, 365, 497], [19, 1863, 13, 41], [1, 96, 2230, 392], [2, 21, 1419, 1421], [88, 108, 6, 2, 148], [1, 118, 596, 76, 205, 2, 980], [133, 276, 29, 2983], [1, 118, 1280, 76], [178, 5, 3, 1185, 25], [2, 139], [2, 2984, 54, 161, 5, 168], [1, 44, 266, 4, 102], [2, 28, 5, 7], [42, 87, 3, 25], [717, 4, 88, 1422], [43, 433, 46, 28], [921, 548, 1281, 22], [285, 330, 4, 2985, 9, 2231, 3, 1, 7, 277, 219], [2986, 5, 6, 2, 286], [2, 381, 5, 103], [17, 393, 3, 178], [7, 185, 1423, 76], [7, 2987, 3, 2, 33], [16, 191, 6, 411], [2, 22, 5, 13], [8, 37, 294, 46, 54, 4, 64], [1, 8, 440, 2, 33], [22, 3, 2, 25],
 1, 23], [40, 11, 73, 2093, 3, 30], [34, 652, 463, 67, 866], [7, 368, 74, 6, 68], [3, 98], [34, 16, 3853, 6, 223], [1, 146, 220, 11, 1070, 168, 337], [25, 5, 12, 124], [1, 2658, 17, 78], [21, 242, 11, 17, 765], [2, 78, 5, 7], [292, 410, 27, 91, 3, 2, 279], [1, 13, 9, 21, 59], [19, 4, 1718], [29, 4874, 95, 187, 3, 2, 26], [12, 9, 7, 263, 456], [34, 135, 4, 31], [66, 89, 318, 156, 152], [179, 4, 147, 3, 1, 44], [2, 8, 5, 470, 3, 2, 111], [10, 9, 7, 277, 77], [7, 59, 3, 2, 64], [50, 3, 1, 28], [3, 73, 4, 41], [950, 4, 29, 261], [59, 3, 2, 64], [1, 1393, 545], [1364, 3, 2, 44], [31, 356, 3, 1, 16, 495], [2, 27, 494, 26], [14, 5, 1, 123], [21, 185, 6, 1, 100, 172], [2, 2869, 3, 2, 30], [1, 1057, 436, 1562], [1, 41, 4, 19], [464, 465, 609, 490, 11, 199, 1344], [260, 3447, 226, 1586], [1242, 3, 1, 41], [2574, 69, 322, 3, 2, 125], [13, 24, 205, 26], [1, 18, 6, 1, 1214, 6, 1, 1496, 68], [26, 3, 55], [1, 461, 4, 109, 479, 758], [61, 494, 52, 670, 240], [18, 1332, 153, 3422], [1, 133], [1, 47, 20, 1, 788], [36, 4, 1, 18], [87, 4, 1, 47, 3, 1, 3817], [236, 3, 325], [77, 32, 6, 48], [2, 269, 5, 623, 6, 124], [212, 725, 205, 1054], [2282, 54, 178, 4, 2, 286], [1, 177, 58, 318, 1, 152], [537, 3, 1, 56], [53, 218, 3, 1, 96, 81], [638, 7, 6, 124], [2, 173, 72, 51, 430, 291, 3, 2, 42, 72], [60, 4, 1, 16, 150, 172], [10, 134, 673, 107], [29, 28], [1, 39, 5, 1500, 3, 1, 28], [793, 45, 122, 1324], [8, 391, 1163, 6, 69], [1, 41, 3, 2, 64], [2, 94, 6, 73, 4, 2, 8], [10, 1594, 892, 3, 160, 36], [674, 310, 3, 1, 531, 232], [17, 455, 3, 61], [66, 89], [38, 4, 1, 67], [14, 5, 1, 147], [17, 9, 10, 66, 545], [2, 36, 4, 1, 81], [10, 67, 32, 6, 2, 3385], [19, 837, 3, 1, 44], [75, 11, 1910, 9, 419], [1, 229, 299, 41], [14, 5, 1, 1761], [7, 245, 1462, 1327], [1117, 5, 6, 2, 131], [1236, 4, 2, 501], [1, 10, 172], [12, 95], [1344, 609, 102, 6, 366, 4, 44], [1 ...

# %%
x_tokens.index_word
# Out:
# {1: 'a',
#  2: 'the',
#  3: 'on',
#  4: 'of',
#  5: 'is',
#  6: 'in',
#  7: 'white',
#  8: 'man',
#  9: 'and',
#  10: 'black',
#  11: 'with',
#  12: 'red',
#  13: 'blue',
#  14: 'this',
#  15: 'woman',
#  16: 'green',
#  17: 'brown',
#  18: 'person',
#  19: 'two',
#  20: 'wearing',
#  21: 'yellow',
#  22: 'sign',
#  23: 'train',
#  24: 'sky',
#  25: 'wall',
#  26: 'water',
#  27: 'are',
#  28: 'building',
#  29: 'an',
#  30: 'table',
#  31: 'people',
#  32: 'standing',
#  33: 'street',
#  34: 'large',
#  35: 'tennis',
#  36: 'head',
#  37: 'sitting',
#  38: 'part',
#  39: 'clock',
#  40: 'dog',
#  41: 'bus',
#  42: 'small',
#  43: 'light',
#  44: 'plate',
#  45: 'holding',
#  46: 'to',
#  47: 'cat',
#  48: 'grass',
#  49: 'shirt',
#  50: 'window',
#  51: 'has',
#  52: 'at',
#  53: 'orange',
#  54: 'side',
#  55: 'ground',
#  56: 'plane',
#  57: 'bear',
#  58: 'boy',
#  59: 'car',
#  60: 'top',
#  61: 'giraffe',
#  62: 'girl',
#  63: 'playing',
#  64: 'road',
#  65: 'snow',
#  66: 'baseball',
#  67: 'horse',
#  68: 'field',
#  69: 'air',
#  70: 'bench',
#  71: 'silver',
#  72: 'elephant',
#  73: 'front',
#  74: 'walking',
#  75: 'pizza',
#  76: 'tree',
#  77: 'zebra',
#  78: 'toilet',
#  79: 'hair',
#  80: 'down',
#  81: 'bird',
#  82: 'riding',
#  83: 'umbrella',
#  84: 'truck',
#  85: 'three',
#  86: 'skateboard',
#  87: 'picture',
#  88: 'wooden',
#  89: 'player',
#  90: 'hat',
#  91: 'parked',
#  92: 'pole',
#  93: 'ball',
#  94: 'frisbee',
#  95: 'boat',
#  96: 'gray',
#  97: 'pink',
#  98: 'motorcycle',
#  99: 'bed',
#  100: 'glass',
#  101: 'kite',
#  102: 'food',
#  103: 'grey',
#  104: 'flying',
#  105: 'hand',
#  106: 'by',
#  107: 'face',
#  108: 'floor',
#  109: 'metal',
#  110: 'beach',
#  111: 'phone',
#  112: 'long',
#  113: 'dark',
#  114: 'board',
#  115: 'young',
#  116: 'back',
#  117: 'surfboard',
#  118: 'tall',
#  119: 'tower',
#  120: 'sheep',
#  121: 'hanging',
#  122: 'up',
#  123: 'cow',
#  124: 'color',
#  125: 'laptop',
#  126: 'bike',
#  127: 'stop',
#  128: 'airplane',
#  129: 'traffic',
#  130: 'eating',
#  131: 'bowl',
#  132: 'bathroom',
#  133: 'chair',
#  134: 'helmet',
#  135: 'group',
#  136: 'clouds',
#  137: 'mans',
#  138: 'for',
#  139: 'sidewalk',
#  140: 'clear',
#  141: 'fire',
#  142: 'hydrant',
#  143: 'tracks',
#  144: 'looking',
#  145: 'it',
#  146: 'computer',
#  147: 'cake',
#  148: 'room',
#  149: 'next',
#  150: 'colored',
#  151: 'round',
#  152: 'bat',
#  153: 'over',
#  154: 'near',
#  155: 'men',
#  156: 'his',
#  157: 'child',
#  158: 'teddy',
#  159: 'from',
#  160: 'giraffes',
#  161: 'door',
#  162: 'left',
#  163: 'old',
#  164: 'desk',
#  165: 'fence',
#  166: 'photo',
#  167: 'kitchen',
#  168: 'open',
#  169: 'baby',
#  170: 'wood',
#  171: 'glasses',
#  172: 'vase',
#  173: 'big',
#  174: 'ocean',
#  175: 'that',
#  176: 'racket',
#  177: 'little',
#  178: 'mirror',
#  179: 'piece',
#  180: 'laying',
#  181: 'outside',
#  182: 'jacket',
#  183: 'zebras',
#  184: 'skiing',
#  185: 'flowers',
#  186: 'lights',
#  187: 'out',
#  188: 'ceiling',
#  189: 'paper',
#  190: 'surfing',
#  191: 'trees',
#  192: 'sink',
#  193: 'bananas',
#  194: 'right',
#  195: 'letter',
#  196: 'number',
#  197: 'box',
#  198: 'court',
#  199: 'purple',
#  200: 'cup',
#  201: 'behind',
#  202: 'post',
#  203: 'elephants',
#  204: 'bottle',
#  205: 'above',
#  206: 'tie',
#  207: 'one',
#  208: 'lamp',
#  209: 'tan',
#  210: 'leaves',
#  211: 'ski',
#  212: 'four',
#  213: 'cell',
#  214: 'game',
#  215: 'flag',
#  216: 'plastic',
#  217: 'brick',
#  218: 'eye',
#  219: 'couch',
#  220: 'screen',
#  221: 'cap',
#  222: 'bright',
#  223: 'background',
#  224: 'lady',
#  225: 'park',
#  226: 'ear',
#  227: 'skier',
#  228: 'cows',
#  229: 'double',
#  230: 'pants',
#  231: 'under',
#  232: 'tail',
#  233: 'wheel',
#  234: 'flower',
#  235: 'camera',
#  236: 'guy',
#  237: 'there',
#  238: 'bag',
#  239: 'covered',
#  240: 'edge',
#  241: 'counter',
#  242: 'banana',
#  243: 'pair',
#  244: 'surfer',
#  245: 'short',
#  246: 'parking',
#  247: 'taken',
#  248: 'sandwich',
#  249: 'city',
#  250: 'very',
#  251: 'horses',
#  252: 'scene',
#  253: 'made',
#  254: 'sand',
#  255: 'visible',
#  256: 'bunch',
#  257: 'suitcase',
#  258: 'fruit',
#  259: 'around',
#  260: 'gold',
#  261: 'engine',
#  262: 'through',
#  263: 'seat',
#  264: 'mountain',
#  265: 'soccer',
#  266: 'full',
#  267: 'shoes',
#  268: 'dogs',
#  269: 'house',
#  270: 'line',
#  271: 'tv',
#  272: 'bicycle',
#  273: 'hill',
#  274: 'view',
#  275: 'together',
#  276: 'inside',
#  277: 'striped',
#  278: 'women',
#  279: 'dirt',
#  280: 'some',
#  281: 'hot',
#  282: 'track',
#  283: 'suit',
#  284: 'nose',
#  285: 'colorful',
#  286: 'vehicle',
#  287: 'row',
#  288: 'womans',
#  289: 'station',
#  290: 'hands',
#  291: 'trunk',
#  292: 'these',
#  293: 'wine',
#  294: 'off',
#  295: 'apple',
#  296: 'jet',
#  297: 'eyes',
#  298: 'tire',
#  299: 'decker',
#  300: 'area',
#  301: 'shelf',
#  302: 'signs',
#  303: 'slice',
#  304: 'against',
#  305: 'shorts',
#  306: 'her',
#  307: 'skateboarder',
#  308: 'skateboarding',
#  309: 'shadow',
#  310: 'painted',
#  311: 'cloud',
#  312: 'reflection',
#  313: 'pot',
#  314: 'statue',
#  315: 'smiling',
#  316: 'wii',
#  317: 'broccoli',
#  318: 'swinging',
#  319: 'refrigerator',
#  320: 'leg',
#  321: 'handle',
#  322: 'logo',
#  323: 'can',
#  324: 'birds',
#  325: 'snowboard',
#  326: 'skis',
#  327: 'shoe',
#  328: 'being',
#  329: 'grazing',
#  330: 'pillow',
#  331: 'corner',
#  332: 'coffee',
#  333: 'animals',
#  334: 'wave',
#  335: 'tray',
#  336: 'several',
#  337: 'windows',
#  338: 'sunglasses',
#  339: 'plant',
#  340: 'many',
#  341: 'square',
#  342: 'half',
#  343: 'carrying',
#  344: 'display',
#  345: 'oven',
#  346: 'driving',
#  347: 'leaning',
#  348: 'stand',
#  349: 'knife',
#  350: 'tile',
#  351: 'bears',
#  352: 'microwave',
#  353: 'bridge',
#  354: 'stone',
#  355: 'body',
#  356: 'running',
#  357: 'lot',
#  358: 'sun',
#  359: 'remote',
#  360: 'letters',
#  361: 'leaf',
#  362: 'players',
#  363: 'mouse',
#  364: 'meter',
#  365: 'book',
#  366: 'middle',
#  367: 'rock',
#  368: 'animal',
#  369: 'neck',
#  370: 'kid',
#  371: 'bread',
#  372: 'cut',
#  373: 'jeans',
#  374: 'stuffed',
#  375: 'passenger',
#  376: 'television',
#  377: 'container',
#  378: 'towel',
#  379: 'lying',
#  380: 'batter',
#  381: 'roof',
#  382: 'stove',
#  383: 'van',
#  384: 'donut',
#  385: 'jumping',
#  386: 'other',
#  387: 'into',
#  388: 'pile',
#  389: 'dish',
#  390: 'slope',
#  391: 'doing',
#  392: 'basket',
#  393: 'frame',
#  394: 'day',
#  395: 'keyboard',
#  396: 'concrete',
#  397: 'runway',
#  398: 'fork',
#  399: 'cats',
#  400: 'wet',
#  401: 'boats',
#  402: 'coat',
#  403: 'luggage',
#  404: 'mouth',
#  405: 'stripes',
#  406: 'foreground',
#  407: 'base',
#  408: 'empty',
#  409: 'sleeping',
#  410: 'cars',
#  411: 'distance',
#  412: 'american',
#  413: 'arm',
#  414: 'dress',
#  415: 'blonde',
#  416: 'boys',
#  417: 'motorcycles',
#  418: 'girls',
#  419: 'cheese',
#  420: 'signal',
#  421: 'surf',
#  422: 'going',
#  423: 'trick',
#  424: 'branch',
#  425: 'monitor',
#  426: 'says',
#  427: 'ready',
#  428: 'fridge',
#  429: 'pan',
#  430: 'its',
#  431: 'beautiful',
#  432: 'persons',
#  433: 'attached',
#  434: 'faucet',
#  435: 'river',
#  436: 'cutting',
#  437: 'wheels',
#  438: 'mid',
#  439: 'chairs',
#  440: 'crossing',
#  441: 'cabinet',
#  442: 'each',
#  443: 'flat',
#  444: 'during',
#  445: 'bottom',
#  446: 'male',
#  447: 'scissors',
#  448: 'taking',
#  449: 'beside',
#  450: 'painting',
#  451: 'stripe',
#  452: 'oranges',
#  453: 'steel',
#  454: 'rail',
#  455: 'spot',
#  456: 'cover',
#  457: 'uniform',
#  458: 'daytime',
#  459: 'umbrellas',
#  460: 'writing',
#  461: 'set',
#  462: 'name',
#  463: 'watching',
#  464: 'chocolate',
#  465: 'doughnut',
#  466: 'tag',
#  467: 'kites',
#  468: 'shade',
#  469: 'rocks',
#  470: 'talking',
#  471: 'case',
#  472: 'toy',
#  473: 'zoo',
#  474: 'along',
#  475: 'sauce',
#  476: 'filled',
#  477: 'polar',
#  478: 'lettering',
#  479: 'framed',
#  480: 'patch',
#  481: 'time',
#  482: 'coming',
#  483: 'video',
#  484: 'foot',
#  485: 'apples',
#  486: 't',
#  487: 'pulling',
#  488: 'snowboarder',
#  489: 'lines',
#  490: 'like',
#  491: 'shiny',
#  492: 'couple',
#  493: 'skate',
#  494: 'drinking',
#  495: 'surface',
#  496: 'facing',
#  497: 'cart',
#  498: 'sweater',
#  499: 'design',
#  500: 'lid',
#  501: 'sea',
#  502: 'motorbike',
#  503: 'children',
#  504: 'roll',
#  505: 'herd',
#  506: 'turned',
#  507: 'trash',
#  508: 'buildings',
#  509: 'no',
#  510: 'tank',
#  511: 'posing',
#  512: 'cone',
#  513: 'wire',
#  514: 'cooked',
#  515: 'button',
#  516: 'controller',
#  517: 'word',
#  518: 'lit',
#  519: 'living',
#  520: 'arrow',
#  521: 'circle',
#  522: 'pattern',
#  523: 'using',
#  524: 'center',
#  525: 'spoon',
#  526: 'about',
#  527: 'feet',
#  528: 'platform',
#  529: 'bun',
#  530: 'sofa',
#  531: 'planes',
#  532: 'stack',
#  533: 'way',
#  534: 'bedroom',
#  535: 'railing',
#  536: 'numbers',
#  537: 'cross',
#  538: 'airport',
#  539: 'spotted',
#  540: 'asian',
#  541: 'golden',
#  542: 'carrots',
#  543: 'donuts',
#  544: 'vegetables',
#  545: 'glove',
#  546: 'porcelain',
#  547: 'sits',
#  548: 'not',
#  549: 'across',
#  550: 'pavement',
#  551: 'mug',
#  552: 'backpack',
#  553: 'bikes',
#  554: 'store',
#  555: 'he',
#  556: 'waiting',
#  557: 'forest',
#  558: 'blanket',
#  559: 'written',
#  560: 'female',
#  561: 'cream',
#  562: 'cloudy',
#  563: 'wing',
#  564: 'pitcher',
#  565: 'trains',
#  566: 'toothbrush',
#  567: 'getting',
#  568: 'cloth',
#  569: 'pool',
#  570: 'rug',
#  571: 'older',
#  572: 'fluffy',
#  573: 'ramp',
#  574: 'soup',
#  575: 'dirty',
#  576: 'kids',
#  577: 'section',
#  578: 'skiers',
#  579: 'public',
#  580: 'photograph',
#  581: 'ceramic',
#  582: 'reading',
#  583: 'fixture',
#  584: 'five',
#  585: 'police',
#  586: 'wears',
#  587: 'end',
#  588: 'beer',
#  589: 'skating',
#  590: 'held',
#  591: 'buses',
#  592: 'horns',
#  593: 'waves',
#  594: 'snowboarding',
#  595: 'something',
#  596: 'palm',
#  597: 'plaid',
#  598: 'tarmac',
#  599: 'print',
#  600: '\u200b\u200b',
#  601: 'object',
#  602: 'sliced',
#  603: 'carrot',
#  604: 'restaurant',
#  605: 'pieces',
#  606: 'shower',
#  607: 'plates',
#  608: 'home',
#  609: 'shaped',
#  610: 'fur',
#  611: 'dressed',
#  612: 'sticker',
#  613: 'image',
#  614: 'throwing',
#  615: 'between',
#  616: 'stainless',
#  617: 'moving',
#  618: 'beak',
#  619: 'hole',
#  620: 'looks',
#  621: 'license',
#  622: 'mountains',
#  623: 'beige',
#  624: '2',
#  625: 'tomato',
#  626: 'school',
#  627: 'safety',
#  628: 'finger',
#  629: 'their',
#  630: 'multi',
#  631: 'vest',
#  632: 'cellphone',
#  633: 'pillows',
#  634: 'jersey',
#  635: 'snowy',
#  636: 'holds',
#  637: 'chain',
#  638: 'blender',
#  639: 'adult',
#  640: 'performing',
#  641: 'childs',
#  642: 'curtain',
#  643: 'night',
#  644: 'paint',
#  645: 'motor',
#  646: 'clean',
#  647: 'legs',
#  648: 'watch',
#  649: 'teeth',
#  650: 'railroad',
#  651: 'woods',
#  652: 'crowd',
#  653: 'straw',
#  654: 'pointing',
#  655: 'outdoors',
#  656: 'goggles',
#  657: 'swing',
#  658: 'calm',
#  659: 'tiles',
#  660: 'sticking',
#  661: 'seated',
#  662: 'wild',
#  663: 'hit',
#  664: 'cement',
#  665: 'pen',
#  666: 'curb',
#  667: 'grassy',
#  668: 'style',
#  669: 'haired',
#  670: 'lake',
#  671: 'thin',
#  672: 'knob',
#  673: 'covering',
#  674: 'words',
#  675: 'close',
#  676: 'shining',
#  677: 'all',
#  678: 'doughnuts',
#  679: 'different',
#  680: 'outfit',
#  681: 'flight',
#  682: 'graffiti',
#  683: 'carriage',
#  684: 'working',
#  685: 'meal',
#  686: 'tusk',
#  687: 'seen',
#  688: 'wrist',
#  689: 'lap',
#  690: 'suv',
#  691: 'doors',
#  692: 'bull',
#  693: 'taxi',
#  694: 'tea',
#  695: 'decorative',
#  696: 'fan',
#  697: 'deep',
#  698: 'ears',
#  699: 'bush',
#  700: 'walk',
#  701: 'leather',
#  702: 'lawn',
#  703: 'fashioned',
#  704: 'windshield',
#  705: 'smoke',
#  706: 'worn',
#  707: 'meat',
#  708: 'closed',
#  709: 'ice',
#  710: 'liquid',
#  711: 'birthday',
#  712: 'slices',
#  713: 'tabby',
#  714: 'tongue',
#  715: 'preparing',
#  716: 'french',
#  717: 'intersection',
#  718: 'rain',
#  719: 'skirt',
#  720: 'banner',
#  721: 'traveling',
#  722: 'match',
#  723: 'tiled',
#  724: 'yard',
#  725: 'clocks',
#  726: 'opened',
#  727: 'neon',
#  728: 'enclosure',
#  729: 'stacked',
#  730: 'eyeglasses',
#  731: 'towels',
#  732: 'jar',
#  733: 'skies',
#  734: 'setting',
#  735: 'vases',
#  736: 'brushing',
#  737: 'fries',
#  738: 'surfers',
#  739: 'carpet',
#  740: 'eaten',
#  741: 'lots',
#  742: 'poles',
#  743: 'pasture',
#  744: 'blond',
#  745: 'brush',
#  746: 'catching',
#  747: 'here',
#  748: 'vegetable',
#  749: 'furry',
#  750: 'six',
#  751: 'showing',
#  752: 'huge',
#  753: 'office',
#  754: 'upside',
#  755: 'broken',
#  756: 'rack',
#  757: 'scarf',
#  758: 'stairs',
#  759: 'outdoor',
#  760: 'tip',
#  761: 'hood',
#  762: 'log',
#  763: 'stick',
#  764: 'mounted',
#  765: 'spots',
#  766: 'curly',
#  767: 'resting',
#  768: 'kitten',
#  769: 'shore',
#  770: 'chicken',
#  771: 'ripe',
#  772: 'racquet',
#  773: 'guys',
#  774: 'toddler',
#  775: 'gate',
#  776: 'vehicles',
#  777: 'cab',
#  778: 'duck',
#  779: 'tub',
#  780: 'dining',
#  781: 'rectangular',
#  782: 'wagon',
#  783: 'circular',
#  784: 'place',
#  785: 'having',
#  786: 'headlight',
#  787: 'family',
#  788: 'collar',
#  789: 'bucket',
#  790: 'pepper',
#  791: 'cooking',
#  792: 'roman',
#  793: 'catcher',
#  794: 'bottles',
#  795: 'gloves',
#  796: 'lift',
#  797: 'egg',
#  798: 'panda',
#  799: 'floral',
#  800: 'monkey',
#  801: 'fresh',
#  802: 'candles',
#  803: 'toppings',
#  804: 'delicious',
#  805: 'drink',
#  806: 'cardboard',
#  807: 'items',
#  808: 'pictures',
#  809: 'rear',
#  810: 'band',
#  811: 'telephone',
#  812: 'paved',
#  813: 'machine',
#  814: 'holder',
#  815: 'cord',
#  816: 'walls',
#  817: 'interior',
#  818: 'curved',
#  819: 'church',
#  820: 'growing',
#  821: 'commercial',
#  822: 'dinner',
#  823: 'blurry',
#  824: 'sit',
#  825: 'vintage',
#  826: 'branches',
#  827: 'net',
#  828: 'apron',
#  829: 'fighter',
#  830: 'electric',
#  831: 'play',
#  832: 'leash',
#  833: 'high',
#  834: 'path',
#  835: 'rider',
#  836: 'used',
#  837: 'sandwiches',
#  838: 'crust',
#  839: 'happy',
#  840: 'tent',
#  841: 'partially',
#  842: 'boots',
#  843: 'glowing',
#  844: 'thick',
#  845: 'dock',
#  846: 'scooter',
#  847: 'poster',
#  848: 'bar',
#  849: 'block',
#  850: 'trim',
#  851: 'panel',
#  852: 'napkin',
#  853: 'wetsuit',
#  854: 'airplanes',
#  855: 'military',
#  856: 'floating',
#  857: 'puppy',
#  858: 'garbage',
#  859: 'sheet',
#  860: 'antique',
#  861: 'grill',
#  862: 'clothing',
#  863: 'subway',
#  864: 'platter',
#  865: 'cabinets',
#  866: 'race',
#  867: 'iron',
#  868: 'ring',
#  869: 'umpire',
#  870: 'as',
#  871: 'text',
#  872: 'bending',
#  873: 'tiny',
#  874: 'asphalt',
#  875: 'hotdog',
#  876: 'surfboards',
#  877: 'clothes',
#  878: 'rolling',
#  879: 'flags',
#  880: 'salad',
#  881: 'breakfast',
#  882: 'books',
#  883: 'pepperoni',
#  884: 'have',
#  885: 'boarding',
#  886: 'swimming',
#  887: 'busy',
#  888: 'decorated',
#  889: 'restroom',
#  890: 'kneeling',
#  891: 'steps',
#  892: 'horn',
#  893: 'rope',
#  894: 'bare',
#  895: 'shape',
#  896: 'clay',
#  897: 'glazed',
#  898: 'label',
#  899: 'ship',
#  900: 'soda',
#  901: 'mostly',
#  902: 'pie',
#  903: 'necklace',
#  904: 'bags',
#  905: 'frosting',
#  906: 'link',
#  907: 'while',
#  908: 'plain',
#  909: 'they',
#  910: 'wings',
#  911: 'goat',
#  912: 'sprinkles',
#  913: 'skater',
#  914: 'single',
#  915: 'hitting',
#  916: 'urinal',
#  917: 'railway',
#  918: 'dessert',
#  919: 'rice',
#  920: 'landing',
#  921: 'do',
#  922: 'plants',
#  923: 'parrot',
#  924: 'highway',
#  925: 'paddle',
#  926: 'trail',
#  927: 'juice',
#  928: 'rainbow',
#  929: 'slat',
#  930: 'entrance',
#  931: 'work',
#  932: 'kettle',
#  933: 'balcony',
#  934: 'forefront',
#  935: 'stopped',
#  936: 'shot',
#  937: 'patio',
#  938: 'shop',
#  939: 'stool',
#  940: 'shaker',
#  941: 'icing',
#  942: 'falling',
#  943: 'hay',
#  944: 'dead',
#  945: 'winter',
#  946: 'lunch',
#  947: 'socks',
#  948: 'control',
#  949: 'headlights',
#  950: 'propeller',
#  951: 'bent',
#  952: 'be',
#  953: 'dot',
#  954: 'touching',
#  955: 'country',
#  956: 'rocky',
#  957: 'mini',
#  958: 'bow',
#  959: 'rusted',
#  960: 'checkered',
#  961: 'tomatoes',
#  962: 'suitcases',
#  963: 'mound',
#  964: 'baked',
#  965: 'power',
#  966: 'cattle',
#  967: 'lighthouse',
#  968: 'wind',
#  969: 'countertop',
#  970: 'perched',
#  971: 'rusty',
#  972: 'figure',
#  973: 'pocket',
#  974: 'sleeve',
#  975: 'star',
#  976: 'who',
#  977: 'colour',
#  978: 'mark',
#  979: 'stroller',
#  980: 'horizon',
#  981: 'medium',
#  982: 'cage',
#  983: 'butter',
#  984: 'sill',
#  985: 'multicolored',
#  986: 'art',
#  987: 'bushes',
#  988: 'ornate',
#  989: 'walkway',
#  990: 'terminal',
#  991: 'fireplace',
#  992: 'candle',
#  993: 'stuff',
#  994: 'aircraft',
#  995: 'hard',
#  996: 'trolley',
#  997: 'meters',
#  998: 'key',
#  999: 'midair',
#  1000: 'pulled',
#  ...}

# %%
reverse_source_word_index=x_tokens.index_word
reverse_source_word_index[2227]
# Out:
# 'indoor'

# %%
#padding with post (appending zeros at the end to equalize sentence length)
from keras.preprocessing.sequence import pad_sequences
x_tr = pad_sequences(x_tr,maxlen = trmaxlen_english,padding = 'post')
x_val = pad_sequences(x_val,maxlen = trmaxlen_english,padding = 'post')

# +1 for padding
x_voc_size   =  len(x_tokens.word_index) +1
print("No of unique words in English",x_voc_size)
# Out:
# No of unique words in English 5547

# %%
#Tokening the sentences using Keras tokenizer -Malayalam data
from keras.preprocessing.text import Tokenizer
y_tokens = Tokenizer()
y_tokens.fit_on_texts(y_tr)
y_tr = y_tokens.texts_to_sequences(y_tr)
y_val = y_tokens.texts_to_sequences(y_val)
print('x_tr:',y_tr)
print(len(y_tokens.word_index))
print('x_val:',y_val)

# from keras.preprocessing.text import Tokenizer
# x_tokens = Tokenizer()
# x_tokens.fit_on_texts(x_tr)
# x_tr = x_tokens.texts_to_sequences(x_tr)
# x_val = x_tokens.texts_to_sequences(x_val)
# print('x_tr:',x_tr)
# print(len(x_tokens.word_index))
# print('x_val:',x_val)
# Out:
 20, 13, 82, 2], [1, 20, 13, 1693, 18, 446, 2], [1, 82, 96, 24, 2], [1, 205, 583, 1988, 151, 612, 2], [1, 19, 6, 18, 60, 2], [1, 2774, 8, 27, 2], [1, 98, 4, 3, 4049, 111, 2], [1, 12, 6, 9, 274, 607, 2], [1, 23, 122, 2], [1, 53, 50, 93, 196, 157, 731, 2], [1, 3, 45, 4, 134, 143, 2], [1, 14, 532, 1511, 2], [1, 16, 6, 9, 271, 77, 2], [1, 89, 4, 10, 60, 2], [1, 107, 72, 2], [1, 40, 62, 2], [1, 264, 8, 1048, 2], [1, 89, 4, 60, 2], [1, 3, 890, 1203, 2], [1, 45, 4, 1994, 2], [1, 25, 1134, 142, 66, 2], [1, 167, 2], [1, 11, 3, 113, 2], [1, 137, 2706, 18, 259, 2], [1, 34, 4, 2675, 7054, 2], [1, 1501, 1701, 6715, 2], [1, 27, 40, 2], [1, 1191, 716, 15, 526, 253, 2], [1, 231, 269, 4129, 2], [1, 1572, 291, 2], [1, 702, 3615, 1065, 400, 2], [1, 98, 55, 108, 49, 2], [1, 1962, 102, 356, 15, 5, 2], [1, 98, 2], [1, 116, 725, 869, 1260, 2], [1, 1166, 208, 133, 56, 1442, 2], [1, 5, 4, 624, 42, 2], [1, 3, 187, 2], [1, 887, 22, 35, 2], [1, 3, 5, 8, 38, 2], [1, 2113, 35, 97, 2], [1, 388, 4, 5, 2], [1, 77, 193, 31, 7, 2], [1, 697, 152, 273, 33, 24, 2], [1, 919, 55, 255, 1035, 2], [1, 260, 8, 2472, 58, 226, 2], [1, 3, 26, 129, 157, 731, 2], [1, 3, 382, 701, 2], [1, 41, 13, 43, 242, 2], [1, 766, 9, 13, 2], [1, 23, 70, 26, 758, 594, 323, 24, 2], [1, 25, 13, 564, 55, 2], [1, 178, 125, 2510, 6103, 2], [1, 3, 48, 2], [1, 107, 39, 3415, 2], [1, 74, 890, 2], [1, 14, 59, 5515, 101, 2], [1, 89, 4, 3 ...

# %%
# target_word_index[2227]

# %%
#padding with post (appending zeros at the end to equalize sentence length)
from keras.preprocessing.sequence import pad_sequences
y_tr = pad_sequences(y_tr,maxlen = trmaxlen_malayalam,padding = 'post')
y_val = pad_sequences(y_val,maxlen = trmaxlen_malayalam,padding = 'post')

# +1 for padding
y_voc_size   =  len(y_tokens.word_index) +1
print("No of unique words in English",y_voc_size)
# Out:
# No of unique words in English 8721

# %%
#Tokening the sentences using Keras tokenizer -Malayalam data
# from keras.preprocessing.text import Tokenizer
# x_tokens = Tokenizer()
# x_tokens.fit_on_texts(x_tr)
x_tt = x_tokens.texts_to_sequences(x_tt)
print('x_tt:',x_tt)
print(len(x_tokens.word_index))
# Out:
3, 2, 241], [6, 2, 174], [15, 494, 159, 293, 100], [77, 32, 11, 61], [19, 155, 27, 65, 885], [67, 586, 3, 36], [29, 163, 664, 70, 11, 3, 145], [1, 8, 3, 2, 891, 4, 1, 23], [100, 50, 3, 269], [1, 15, 20, 1, 10, 134], [2, 865, 27, 7], [2091, 3, 1, 44], [1, 13, 66, 221], [14, 5, 2, 24], [34, 4352, 1374], [115, 62, 180, 3, 2, 110], [16, 9, 7, 1576, 22, 205, 12, 22], [7, 516, 6, 105], [227, 3, 1837, 38, 4, 390], [2, 195, 5, 10], [1, 388, 4, 10, 507, 904], [1, 34, 151, 39], [123, 767, 3, 112, 48], [14, 5, 2, 24], [53, 165, 3, 2, 139], [2, 39], [160, 52, 2, 473], [2, 57, 51, 610], [1, 81, 3, 2, 110], [639, 446, 37, 6, 2, 33], [72, 180, 80, 6, 1, 435], [222, 53, 43], [42, 577, 4, 2, 623, 25], [972, 3, 99], [1, 57], [34, 7, 128, 3, 397], [2, 235], [847, 6, 71, 393], [34, 367, 6, 388], [1, 12, 9, 10, 98], [18, 52, 93, 214], [85, 268, 27, 32, 6, 70], [14, 5, 1, 67], [2, 23, 5, 13, 9, 21], [19, 203, 27, 5421, 442, 386], [1, 102, 1420, 5, 201, 2, 241], [213, 111, 149, 46, 1, 137, 226], [14, 5, 1, 34, 211, 390], [16, 9, 7, 33, 22], [1, 40, 6, 2, 26], [1, 157, 130, 1, 75], [1072, 1773, 3, 688], [22, 11, 29, 520, 654, 194], [2, 371, 5, 372], [1, 15, 37, 6, 1, 1816, 3230], [1, 18, 130, 1, 53], [62, 51, 17, 79], [246, 364, 138, 19, 776], [58, 308, 3, 2, 550], [26, 231, 2, 2314], [505, 4, 120, 74], [1, 140, 1513, 24], [4, 622, 6, 411], [1, 158, 57], [342, 4, 1, 1379], [10, 84, 11, 99, 456], [465, 51, 1, 1548, 2973], [967, 51, 1, 245, 1208, 138, 627], [1, 39, 6, 1, 28], [1, 199, 9, 10, 2821], [12, 141, 142, 11, 7, 221], [39, 6, 1, 119], [6, 2, 26], [ ...
# 5546

# %%
from keras.preprocessing.sequence import pad_sequences
x_tt = pad_sequences(x_tt,maxlen = trmaxlen_english,padding = 'post')

# %%
# y_tokens = Tokenizer()
# y_tokens.fit_on_texts(y_tr)
y_tt = y_tokens.texts_to_sequences(y_tt)

# %%
y_tt = pad_sequences(y_tt,maxlen = trmaxlen_english,padding = 'post')

# %%
pip install keras-applications
# Out:
# Requirement already satisfied: keras-applications in /usr/local/lib/python3.10/dist-packages (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications) (1.25.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications) (3.9.0)

# %%
pip install np_utils
# Out:
# Requirement already satisfied: np_utils in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: numpy>=1.0 in /usr/local/lib/python3.10/dist-packages (from np_utils) (1.25.2)

# %%
import pandas as pd
import pickle
import numpy as np
import os
import keras
import tensorflow
from keras_applications.resnet import ResNet50
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense, GlobalAveragePooling2D,BatchNormalization,Flatten,Input, Convolution2D, Dropout, LSTM, TimeDistributed, Embedding, Bidirectional, Activation, RepeatVector,Concatenate
from keras.models import Sequential, Model
from keras.utils import to_categorical
import random
from keras.preprocessing import image, sequence
import matplotlib.pyplot as plt
import keras
from keras import backend as K
import gensim
from numpy import *
import numpy as np
import pandas as pd
import re
from tensorflow.keras.applications.vgg16 import VGG16
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed,Conv2D,MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings

# %%
x_voc=x_voc_size
y_voc=y_voc_size

# %%
x_voc
# Out:
# 5547

# %%
y_voc
# Out:
# 8721

# %%
#Model
x_voc=x_voc_size
y_voc=y_voc_size
latent_dim = 512
embedding_dim=512
#Encoder
encoder_inputs = Input(shape=(trmaxlen_english,))
#The model will take as input an integer matrix of size (batch,input_length)and the largest integer (i.e. word index) in the input
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)
print(encoder_inputs.get_shape)
print(enc_emb.get_shape)
# Out:
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, 25) dtype=float32 (created by layer 'input_1')>>
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, 25, 512) dtype=float32 (created by layer 'embedding')>>

# %%
#Generating a repeat vector from image pixels
img_inputs=Input(shape=(4096,))
d_1=Dense(512, activation='relu')(img_inputs)
r_1=RepeatVector(trmaxlen_english)(d_1)
vf_model = Model(img_inputs, r_1)
vf_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 4096)]            0
#
#  dense (Dense)               (None, 512)               2097664
#
#  repeat_vector (RepeatVecto  (None, 25, 512)           0
#  r)
#
# =================================================================
# Total params: 2097664 (8.00 MB)
# Trainable params: 2097664 (8.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#encoder LSTM Layer 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
#The dimension of each state equals to the LSTM unit number
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)
print(encoder_lstm1.output_shape)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [(None, 25, 512), (None, 512), (None, 512)]

# %%
#LSTM layer 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)
print(encoder_lstm2.output_shape)
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [(None, 25, 512), (None, 512), (None, 512)]

# %%
#Concatenating image features with text input
encoder_output2=Concatenate(axis=-1)([encoder_output2,r_1])

# %%
#LSTM layer 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)
print(encoder_lstm3.output_shape)
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [(None, 25, 512), (None, 512), (None, 512)]

# %%
#Decoder
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))
#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)
print(decoder_inputs.get_shape)
print(dec_emb.get_shape)
# Out:
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, None) dtype=float32 (created by layer 'input_3')>>
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, None, 512) dtype=float32 (created by layer 'embedding_1')>>

# %%
#Decoder LSTM layer1
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])
print(decoder_lstm.output_shape)
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [(None, None, 512), (None, 512), (None, 512)]

# %%
import tensorflow as tf
import os
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K
import numpy as np
from matplotlib import pyplot as plt
from tqdm import tqdm
import keras
from keras import backend as K
from keras import activations, initializers, regularizers, constraints, metrics
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model
from keras.layers import (Dense, Dropout, Activation, Flatten, Reshape, Layer,
                          BatchNormalization, LocallyConnected2D,
                          ZeroPadding2D, Conv2D, MaxPooling2D, Conv2DTranspose,
                          GaussianNoise, UpSampling2D, Input)
#from keras.utils import conv_utils, multi_gpu_model
from keras.layers import Lambda
#from keras.engine import Layer, InputSpec
#from keras.legacy import interfaces

# %%
class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state
            inputs: (batchsize * 1 * de_in_dim)
            states: (batchsize * 1 * de_latent_dim)
            """

            assert_msg = "States must be an iterable. Got {} of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch size * en_seq_len * latent_dim
            W_a_dot_s = K.dot(encoder_out_seq, self.W_a)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>', U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            Ws_plus_Uh = K.tanh(W_a_dot_s + U_a_dot_h)
            if verbose:
                print('Ws+Uh>', Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.squeeze(K.dot(Ws_plus_Uh, self.V_a), axis=-1)
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """

            assert_msg = "States must be an iterable. Got {} of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        fake_state_c = K.sum(encoder_out_seq, axis=1)
        fake_state_e = K.sum(encoder_out_seq, axis=2)  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# %%
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# %%
#dense = Dense(fr_vsize, activation='softmax', name='softmax_layer')
#dense_time = TimeDistributed(dense, name='time_distributed_layer')
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)
#decoder_output = dense_time(decoder_concat_input)
print(decoder_dense.output_shape)
# Out:
# (None, None, 8721)

# %%
model = Model([encoder_inputs,img_inputs, decoder_inputs], decoder_outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 25)]                 0         []
#
#  embedding (Embedding)       (None, 25, 512)              2840064   ['input_1[0][0]']
#
#  input_2 (InputLayer)        [(None, 4096)]               0         []
#
#  lstm (LSTM)                 [(None, 25, 512),            2099200   ['embedding[0][0]']
#                               (None, 512),
#                               (None, 512)]
#
#  dense (Dense)               (None, 512)                  2097664   ['input_2[0][0]']
#
#  lstm_1 (LSTM)               [(None, 25, 512),            2099200   ['lstm[0][0]']
#                               (None, 512),
#                               (None, 512)]
#
#  repeat_vector (RepeatVecto  (None, 25, 512)              0         ['dense[0][0]']
#  r)
#
#  input_3 (InputLayer)        [(None, None)]               0         []
#
#  concatenate (Concatenate)   (None, 25, 1024)             0         ['lstm_1[0][0]',
#                                                                      'repeat_vector[0][0]']
#
#  embedding_1 (Embedding)     (None, None, 512)            4465152   ['input_3[0][0]']
#
#  lstm_2 (LSTM)               [(None, 25, 512),            3147776   ['concatenate[0][0]']
#                               (None, 512),
#                               (None, 512)]
#
#  lstm_3 (LSTM)               [(None, None, 512),          2099200   ['embedding_1[0][0]',
#                               (None, 512),                           'lstm_2[0][1]',
#                               (None, 512)]                           'lstm_2[0][2]']
#
#  attention_layer (Attention  ((None, None, 512),          524800    ['lstm_2[0][0]',
#  Layer)                       (None, None, 25))                      'lstm_3[0][0]']
#
#  concat_layer (Concatenate)  (None, None, 1024)           0         ['lstm_3[0][0]',
#                                                                      'attention_layer[0][0]']
#
#  time_distributed (TimeDist  (None, None, 8721)           8939025   ['concat_layer[0][0]']
#  ributed)
#
# ==================================================================================================
# Total params: 28312081 (108.00 MB)
# Trainable params: 28312081 (108.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model
import tensorflow as tf

# %%
tf.keras.utils.plot_model(
    model,
    to_file='model.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB'
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

checkpoint = ModelCheckpoint("/content/drive/My Drive/Main/modelnmtattention", monitor='val_accuracy')

early_stopping = EarlyStopping(monitor='val_accuracy', patience=5)

callbacks_list = [checkpoint, early_stopping]

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
print("Shape of x_tr:", x_tr.shape)
print("Shape of y_tr:", y_tr.shape)
print("Shape of x_val:", x_val.shape)
print("Shape of y_val:", y_val.shape)
print(len(x_tokens.word_index))
print(len(y_tokens.word_index))
print(x_voc)
print(y_voc)
# Out:
# Shape of x_tr: (28929, 25)
# Shape of y_tr: (28929, 21)
# Shape of x_val: (998, 25)
# Shape of y_val: (998, 21)
# 5546
# 8720
# 5547
# 8721

# %%
trvgg_feature=np.load('/content/drive/My Drive/trainfeature.npy', encoding='bytes')

# %%
dvgg_feature=np.load('/content/drive/My Drive/devfeature.npy', encoding='bytes')

# %%
vgg_train_=trvgg_feature
vgg_val=dvgg_feature

# %%
print(vgg_train_.shape)
# Out:
# (28929, 4096)

# %%
print(vgg_val.shape)
# Out:
# (998, 4096)

# %%
print(x_tr.shape)
# Out:
# (28929, 25)

# %%
y_tr[:,:-1]
# Out:
# array([[   1,  517, 4238, ...,    0,    0,    0],
#        [   1,  148, 3055, ...,    0,    0,    0],
#        [   1,  284,   26, ...,    0,    0,    0],
#        ...,
#        [   1, 1392,    4, ...,    0,    0,    0],
#        [   1,   11,    3, ...,    0,    0,    0],
#        [   1,   21,    8, ...,    0,    0,    0]], dtype=int32)

# %%
print(y_tr[:,:-1].shape)
# Out:
# (28929, 20)

# %%
print(y_tr.shape)
# Out:
# (28929, 21)

# %%
print(vgg_val.shape)
# Out:
# (998, 4096)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history=model.fit([x_tr, vgg_train_, y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,validation_data=([x_val, vgg_val, y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]),epochs=100,batch_size=512)
# Out:
# Epoch 1/100
# 57/57 [==============================] - 71s 902ms/step - loss: 1.8994 - accuracy: 0.7699 - val_loss: 1.3008 - val_accuracy: 0.8230
# Epoch 2/100
# 57/57 [==============================] - 48s 850ms/step - loss: 1.3602 - accuracy: 0.8160 - val_loss: 1.2281 - val_accuracy: 0.8248
# Epoch 3/100
# 57/57 [==============================] - 47s 820ms/step - loss: 1.2915 - accuracy: 0.8211 - val_loss: 1.1726 - val_accuracy: 0.8305
# Epoch 4/100
# 57/57 [==============================] - 46s 814ms/step - loss: 1.2276 - accuracy: 0.8266 - val_loss: 1.1165 - val_accuracy: 0.8379
# Epoch 5/100
# 57/57 [==============================] - 46s 807ms/step - loss: 1.1640 - accuracy: 0.8324 - val_loss: 1.0699 - val_accuracy: 0.8410
# Epoch 6/100
# 57/57 [==============================] - 46s 808ms/step - loss: 1.1038 - accuracy: 0.8367 - val_loss: 1.0249 - val_accuracy: 0.8443
# Epoch 7/100
# 57/57 [==============================] - 46s 807ms/step - loss: 1.0484 - accuracy: 0.8403 - val_loss: 0.9916 - val_accuracy: 0.8475
# Epoch 8/100
# 57/57 [==============================] - 46s 805ms/step - loss: 1.0030 - accuracy: 0.8432 - val_loss: 0.9651 - val_accuracy: 0.8494
# Epoch 9/100
# 57/57 [==============================] - 46s 806ms/step - loss: 0.9596 - accuracy: 0.8460 - val_loss: 0.9433 - val_accuracy: 0.8513
# Epoch 10/100
# 57/57 [==============================] - 46s 804ms/step - loss: 0.9213 - accuracy: 0.8485 - val_loss: 0.9207 - val_accuracy: 0.8532
# Epoch 11/100
# 57/57 [==============================] - 46s 814ms/step - loss: 0.8847 - accuracy: 0.8511 - val_loss: 0.9030 - val_accuracy: 0.8553
# Epoch 12/100
# 57/57 [==============================] - 46s 804ms/step - loss: 0.8473 - accuracy: 0.8541 - val_loss: 0.8875 - val_accuracy: 0.8570
# Epoch 13/100
# 57/57 [==============================] - 46s 811ms/step - loss: 0.8123 - accuracy: 0.8567 - val_loss: 0.8722 - val_accuracy: 0.8575
# Epoch 14/100
# 57/57 [==============================] - 46s 806ms/step - loss: 0.7774 - accuracy: 0.8593 - val_loss: 0.8614 - val_accuracy: 0.8590
# Epoch 15/100
# 57/57 [==============================] - 46s 808ms/step - loss: 0.7423 - accuracy: 0.8628 - val_loss: 0.8476 - val_accuracy: 0.8610
# Epoch 16/100
# 57/57 [==============================] - 46s 812ms/step - loss: 0.7014 - accuracy: 0.8675 - val_loss: 0.8267 - val_accuracy: 0.8650
# Epoch 17/100
# 57/57 [==============================] - 46s 809ms/step - loss: 0
100
# 57/57 [==============================] - 46s 809ms/step - loss: 0.0091 - accuracy: 0.9988 - val_loss: 0.7546 - val_accuracy: 0.9003
# Epoch 94/100
# 57/57 [==============================] - 46s 810ms/step - loss: 0.0083 - accuracy: 0.9990 - val_loss: 0.7517 - val_accuracy: 0.9010
# Epoch 95/100
# 57/57 [==============================] - 46s 810ms/step - loss: 0.0077 - accuracy: 0.9991 - val_loss: 0.7555 - val_accuracy: 0.9007
# Epoch 96/100
# 57/57 [==============================] - 46s 809ms/step - loss: 0.0068 - accuracy: 0.9993 - val_loss: 0.7675 - val_accuracy: 0.8993
# Epoch 97/100
# 57/57 [==============================] - 46s 810ms/step - loss: 0.0066 - accuracy: 0.9994 - val_loss: 0.7605 - val_accuracy: 0.9002
# Epoch 98/100
# 57/57 [==============================] - 46s 808ms/step - loss: 0.0056 - accuracy: 0.9995 - val_loss: 0.7654 - val_accuracy: 0.9011
# Epoch 99/100
# 57/57 [==============================] - 46s 812ms/step - loss: 0.0050 - accuracy: 0.9996 - val_loss: 0.7542 - val_accuracy: 0.9020
# Epoch 100/100
# 57/57 [==============================] - 46s 807ms/step - loss: 0.0047 - accuracy: 0.9997 - val_loss: 0.7656 - val_accuracy: 0.9027

# %%
print(len(x_tokens.word_index))
print(len(y_tokens.word_index))
# Out:
# 5546
# 8720

# %%
import keras
from matplotlib import pyplot as plt
#history = model1.fit(train_x, train_y,validation_split = 0.1, epochs=50, batch_size=4)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.save ("/content/drive/My Drive/Main/modelnmat.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from keras import models
model = models.load_model("/content/drive/My Drive/Main/modelnmtattention")
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
from keras.utils import plot_model
import tensorflow as tf

# %%
tf.keras.utils.plot_model(
    model,
    to_file='model.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB'
)

# %%
y_tokens
print(len(y_tokens.word_index))
# Out:
# 8720

# %%
reverse_target_word_index=y_tokens.index_word
len(reverse_target_word_index)
# Out:
# 8720

# %%
x_tokens.index_word
# Out:
# {1: 'a',
#  2: 'the',
#  3: 'on',
#  4: 'of',
#  5: 'is',
#  6: 'in',
#  7: 'white',
#  8: 'man',
#  9: 'and',
#  10: 'black',
#  11: 'with',
#  12: 'red',
#  13: 'blue',
#  14: 'this',
#  15: 'woman',
#  16: 'green',
#  17: 'brown',
#  18: 'person',
#  19: 'two',
#  20: 'wearing',
#  21: 'yellow',
#  22: 'sign',
#  23: 'train',
#  24: 'sky',
#  25: 'wall',
#  26: 'water',
#  27: 'are',
#  28: 'building',
#  29: 'an',
#  30: 'table',
#  31: 'people',
#  32: 'standing',
#  33: 'street',
#  34: 'large',
#  35: 'tennis',
#  36: 'head',
#  37: 'sitting',
#  38: 'part',
#  39: 'clock',
#  40: 'dog',
#  41: 'bus',
#  42: 'small',
#  43: 'light',
#  44: 'plate',
#  45: 'holding',
#  46: 'to',
#  47: 'cat',
#  48: 'grass',
#  49: 'shirt',
#  50: 'window',
#  51: 'has',
#  52: 'at',
#  53: 'orange',
#  54: 'side',
#  55: 'ground',
#  56: 'plane',
#  57: 'bear',
#  58: 'boy',
#  59: 'car',
#  60: 'top',
#  61: 'giraffe',
#  62: 'girl',
#  63: 'playing',
#  64: 'road',
#  65: 'snow',
#  66: 'baseball',
#  67: 'horse',
#  68: 'field',
#  69: 'air',
#  70: 'bench',
#  71: 'silver',
#  72: 'elephant',
#  73: 'front',
#  74: 'walking',
#  75: 'pizza',
#  76: 'tree',
#  77: 'zebra',
#  78: 'toilet',
#  79: 'hair',
#  80: 'down',
#  81: 'bird',
#  82: 'riding',
#  83: 'umbrella',
#  84: 'truck',
#  85: 'three',
#  86: 'skateboard',
#  87: 'picture',
#  88: 'wooden',
#  89: 'player',
#  90: 'hat',
#  91: 'parked',
#  92: 'pole',
#  93: 'ball',
#  94: 'frisbee',
#  95: 'boat',
#  96: 'gray',
#  97: 'pink',
#  98: 'motorcycle',
#  99: 'bed',
#  100: 'glass',
#  101: 'kite',
#  102: 'food',
#  103: 'grey',
#  104: 'flying',
#  105: 'hand',
#  106: 'by',
#  107: 'face',
#  108: 'floor',
#  109: 'metal',
#  110: 'beach',
#  111: 'phone',
#  112: 'long',
#  113: 'dark',
#  114: 'board',
#  115: 'young',
#  116: 'back',
#  117: 'surfboard',
#  118: 'tall',
#  119: 'tower',
#  120: 'sheep',
#  121: 'hanging',
#  122: 'up',
#  123: 'cow',
#  124: 'color',
#  125: 'laptop',
#  126: 'bike',
#  127: 'stop',
#  128: 'airplane',
#  129: 'traffic',
#  130: 'eating',
#  131: 'bowl',
#  132: 'bathroom',
#  133: 'chair',
#  134: 'helmet',
#  135: 'group',
#  136: 'clouds',
#  137: 'mans',
#  138: 'for',
#  139: 'sidewalk',
#  140: 'clear',
#  141: 'fire',
#  142: 'hydrant',
#  143: 'tracks',
#  144: 'looking',
#  145: 'it',
#  146: 'computer',
#  147: 'cake',
#  148: 'room',
#  149: 'next',
#  150: 'colored',
#  151: 'round',
#  152: 'bat',
#  153: 'over',
#  154: 'near',
#  155: 'men',
#  156: 'his',
#  157: 'child',
#  158: 'teddy',
#  159: 'from',
#  160: 'giraffes',
#  161: 'door',
#  162: 'left',
#  163: 'old',
#  164: 'desk',
#  165: 'fence',
#  166: 'photo',
#  167: 'kitchen',
#  168: 'open',
#  169: 'baby',
#  170: 'wood',
#  171: 'glasses',
#  172: 'vase',
#  173: 'big',
#  174: 'ocean',
#  175: 'that',
#  176: 'racket',
#  177: 'little',
#  178: 'mirror',
#  179: 'piece',
#  180: 'laying',
#  181: 'outside',
#  182: 'jacket',
#  183: 'zebras',
#  184: 'skiing',
#  185: 'flowers',
#  186: 'lights',
#  187: 'out',
#  188: 'ceiling',
#  189: 'paper',
#  190: 'surfing',
#  191: 'trees',
#  192: 'sink',
#  193: 'bananas',
#  194: 'right',
#  195: 'letter',
#  196: 'number',
#  197: 'box',
#  198: 'court',
#  199: 'purple',
#  200: 'cup',
#  201: 'behind',
#  202: 'post',
#  203: 'elephants',
#  204: 'bottle',
#  205: 'above',
#  206: 'tie',
#  207: 'one',
#  208: 'lamp',
#  209: 'tan',
#  210: 'leaves',
#  211: 'ski',
#  212: 'four',
#  213: 'cell',
#  214: 'game',
#  215: 'flag',
#  216: 'plastic',
#  217: 'brick',
#  218: 'eye',
#  219: 'couch',
#  220: 'screen',
#  221: 'cap',
#  222: 'bright',
#  223: 'background',
#  224: 'lady',
#  225: 'park',
#  226: 'ear',
#  227: 'skier',
#  228: 'cows',
#  229: 'double',
#  230: 'pants',
#  231: 'under',
#  232: 'tail',
#  233: 'wheel',
#  234: 'flower',
#  235: 'camera',
#  236: 'guy',
#  237: 'there',
#  238: 'bag',
#  239: 'covered',
#  240: 'edge',
#  241: 'counter',
#  242: 'banana',
#  243: 'pair',
#  244: 'surfer',
#  245: 'short',
#  246: 'parking',
#  247: 'taken',
#  248: 'sandwich',
#  249: 'city',
#  250: 'very',
#  251: 'horses',
#  252: 'scene',
#  253: 'made',
#  254: 'sand',
#  255: 'visible',
#  256: 'bunch',
#  257: 'suitcase',
#  258: 'fruit',
#  259: 'around',
#  260: 'gold',
#  261: 'engine',
#  262: 'through',
#  263: 'seat',
#  264: 'mountain',
#  265: 'soccer',
#  266: 'full',
#  267: 'shoes',
#  268: 'dogs',
#  269: 'house',
#  270: 'line',
#  271: 'tv',
#  272: 'bicycle',
#  273: 'hill',
#  274: 'view',
#  275: 'together',
#  276: 'inside',
#  277: 'striped',
#  278: 'women',
#  279: 'dirt',
#  280: 'some',
#  281: 'hot',
#  282: 'track',
#  283: 'suit',
#  284: 'nose',
#  285: 'colorful',
#  286: 'vehicle',
#  287: 'row',
#  288: 'womans',
#  289: 'station',
#  290: 'hands',
#  291: 'trunk',
#  292: 'these',
#  293: 'wine',
#  294: 'off',
#  295: 'apple',
#  296: 'jet',
#  297: 'eyes',
#  298: 'tire',
#  299: 'decker',
#  300: 'area',
#  301: 'shelf',
#  302: 'signs',
#  303: 'slice',
#  304: 'against',
#  305: 'shorts',
#  306: 'her',
#  307: 'skateboarder',
#  308: 'skateboarding',
#  309: 'shadow',
#  310: 'painted',
#  311: 'cloud',
#  312: 'reflection',
#  313: 'pot',
#  314: 'statue',
#  315: 'smiling',
#  316: 'wii',
#  317: 'broccoli',
#  318: 'swinging',
#  319: 'refrigerator',
#  320: 'leg',
#  321: 'handle',
#  322: 'logo',
#  323: 'can',
#  324: 'birds',
#  325: 'snowboard',
#  326: 'skis',
#  327: 'shoe',
#  328: 'being',
#  329: 'grazing',
#  330: 'pillow',
#  331: 'corner',
#  332: 'coffee',
#  333: 'animals',
#  334: 'wave',
#  335: 'tray',
#  336: 'several',
#  337: 'windows',
#  338: 'sunglasses',
#  339: 'plant',
#  340: 'many',
#  341: 'square',
#  342: 'half',
#  343: 'carrying',
#  344: 'display',
#  345: 'oven',
#  346: 'driving',
#  347: 'leaning',
#  348: 'stand',
#  349: 'knife',
#  350: 'tile',
#  351: 'bears',
#  352: 'microwave',
#  353: 'bridge',
#  354: 'stone',
#  355: 'body',
#  356: 'running',
#  357: 'lot',
#  358: 'sun',
#  359: 'remote',
#  360: 'letters',
#  361: 'leaf',
#  362: 'players',
#  363: 'mouse',
#  364: 'meter',
#  365: 'book',
#  366: 'middle',
#  367: 'rock',
#  368: 'animal',
#  369: 'neck',
#  370: 'kid',
#  371: 'bread',
#  372: 'cut',
#  373: 'jeans',
#  374: 'stuffed',
#  375: 'passenger',
#  376: 'television',
#  377: 'container',
#  378: 'towel',
#  379: 'lying',
#  380: 'batter',
#  381: 'roof',
#  382: 'stove',
#  383: 'van',
#  384: 'donut',
#  385: 'jumping',
#  386: 'other',
#  387: 'into',
#  388: 'pile',
#  389: 'dish',
#  390: 'slope',
#  391: 'doing',
#  392: 'basket',
#  393: 'frame',
#  394: 'day',
#  395: 'keyboard',
#  396: 'concrete',
#  397: 'runway',
#  398: 'fork',
#  399: 'cats',
#  400: 'wet',
#  401: 'boats',
#  402: 'coat',
#  403: 'luggage',
#  404: 'mouth',
#  405: 'stripes',
#  406: 'foreground',
#  407: 'base',
#  408: 'empty',
#  409: 'sleeping',
#  410: 'cars',
#  411: 'distance',
#  412: 'american',
#  413: 'arm',
#  414: 'dress',
#  415: 'blonde',
#  416: 'boys',
#  417: 'motorcycles',
#  418: 'girls',
#  419: 'cheese',
#  420: 'signal',
#  421: 'surf',
#  422: 'going',
#  423: 'trick',
#  424: 'branch',
#  425: 'monitor',
#  426: 'says',
#  427: 'ready',
#  428: 'fridge',
#  429: 'pan',
#  430: 'its',
#  431: 'beautiful',
#  432: 'persons',
#  433: 'attached',
#  434: 'faucet',
#  435: 'river',
#  436: 'cutting',
#  437: 'wheels',
#  438: 'mid',
#  439: 'chairs',
#  440: 'crossing',
#  441: 'cabinet',
#  442: 'each',
#  443: 'flat',
#  444: 'during',
#  445: 'bottom',
#  446: 'male',
#  447: 'scissors',
#  448: 'taking',
#  449: 'beside',
#  450: 'painting',
#  451: 'stripe',
#  452: 'oranges',
#  453: 'steel',
#  454: 'rail',
#  455: 'spot',
#  456: 'cover',
#  457: 'uniform',
#  458: 'daytime',
#  459: 'umbrellas',
#  460: 'writing',
#  461: 'set',
#  462: 'name',
#  463: 'watching',
#  464: 'chocolate',
#  465: 'doughnut',
#  466: 'tag',
#  467: 'kites',
#  468: 'shade',
#  469: 'rocks',
#  470: 'talking',
#  471: 'case',
#  472: 'toy',
#  473: 'zoo',
#  474: 'along',
#  475: 'sauce',
#  476: 'filled',
#  477: 'polar',
#  478: 'lettering',
#  479: 'framed',
#  480: 'patch',
#  481: 'time',
#  482: 'coming',
#  483: 'video',
#  484: 'foot',
#  485: 'apples',
#  486: 't',
#  487: 'pulling',
#  488: 'snowboarder',
#  489: 'lines',
#  490: 'like',
#  491: 'shiny',
#  492: 'couple',
#  493: 'skate',
#  494: 'drinking',
#  495: 'surface',
#  496: 'facing',
#  497: 'cart',
#  498: 'sweater',
#  499: 'design',
#  500: 'lid',
#  501: 'sea',
#  502: 'motorbike',
#  503: 'children',
#  504: 'roll',
#  505: 'herd',
#  506: 'turned',
#  507: 'trash',
#  508: 'buildings',
#  509: 'no',
#  510: 'tank',
#  511: 'posing',
#  512: 'cone',
#  513: 'wire',
#  514: 'cooked',
#  515: 'button',
#  516: 'controller',
#  517: 'word',
#  518: 'lit',
#  519: 'living',
#  520: 'arrow',
#  521: 'circle',
#  522: 'pattern',
#  523: 'using',
#  524: 'center',
#  525: 'spoon',
#  526: 'about',
#  527: 'feet',
#  528: 'platform',
#  529: 'bun',
#  530: 'sofa',
#  531: 'planes',
#  532: 'stack',
#  533: 'way',
#  534: 'bedroom',
#  535: 'railing',
#  536: 'numbers',
#  537: 'cross',
#  538: 'airport',
#  539: 'spotted',
#  540: 'asian',
#  541: 'golden',
#  542: 'carrots',
#  543: 'donuts',
#  544: 'vegetables',
#  545: 'glove',
#  546: 'porcelain',
#  547: 'sits',
#  548: 'not',
#  549: 'across',
#  550: 'pavement',
#  551: 'mug',
#  552: 'backpack',
#  553: 'bikes',
#  554: 'store',
#  555: 'he',
#  556: 'waiting',
#  557: 'forest',
#  558: 'blanket',
#  559: 'written',
#  560: 'female',
#  561: 'cream',
#  562: 'cloudy',
#  563: 'wing',
#  564: 'pitcher',
#  565: 'trains',
#  566: 'toothbrush',
#  567: 'getting',
#  568: 'cloth',
#  569: 'pool',
#  570: 'rug',
#  571: 'older',
#  572: 'fluffy',
#  573: 'ramp',
#  574: 'soup',
#  575: 'dirty',
#  576: 'kids',
#  577: 'section',
#  578: 'skiers',
#  579: 'public',
#  580: 'photograph',
#  581: 'ceramic',
#  582: 'reading',
#  583: 'fixture',
#  584: 'five',
#  585: 'police',
#  586: 'wears',
#  587: 'end',
#  588: 'beer',
#  589: 'skating',
#  590: 'held',
#  591: 'buses',
#  592: 'horns',
#  593: 'waves',
#  594: 'snowboarding',
#  595: 'something',
#  596: 'palm',
#  597: 'plaid',
#  598: 'tarmac',
#  599: 'print',
#  600: '\u200b\u200b',
#  601: 'object',
#  602: 'sliced',
#  603: 'carrot',
#  604: 'restaurant',
#  605: 'pieces',
#  606: 'shower',
#  607: 'plates',
#  608: 'home',
#  609: 'shaped',
#  610: 'fur',
#  611: 'dressed',
#  612: 'sticker',
#  613: 'image',
#  614: 'throwing',
#  615: 'between',
#  616: 'stainless',
#  617: 'moving',
#  618: 'beak',
#  619: 'hole',
#  620: 'looks',
#  621: 'license',
#  622: 'mountains',
#  623: 'beige',
#  624: '2',
#  625: 'tomato',
#  626: 'school',
#  627: 'safety',
#  628: 'finger',
#  629: 'their',
#  630: 'multi',
#  631: 'vest',
#  632: 'cellphone',
#  633: 'pillows',
#  634: 'jersey',
#  635: 'snowy',
#  636: 'holds',
#  637: 'chain',
#  638: 'blender',
#  639: 'adult',
#  640: 'performing',
#  641: 'childs',
#  642: 'curtain',
#  643: 'night',
#  644: 'paint',
#  645: 'motor',
#  646: 'clean',
#  647: 'legs',
#  648: 'watch',
#  649: 'teeth',
#  650: 'railroad',
#  651: 'woods',
#  652: 'crowd',
#  653: 'straw',
#  654: 'pointing',
#  655: 'outdoors',
#  656: 'goggles',
#  657: 'swing',
#  658: 'calm',
#  659: 'tiles',
#  660: 'sticking',
#  661: 'seated',
#  662: 'wild',
#  663: 'hit',
#  664: 'cement',
#  665: 'pen',
#  666: 'curb',
#  667: 'grassy',
#  668: 'style',
#  669: 'haired',
#  670: 'lake',
#  671: 'thin',
#  672: 'knob',
#  673: 'covering',
#  674: 'words',
#  675: 'close',
#  676: 'shining',
#  677: 'all',
#  678: 'doughnuts',
#  679: 'different',
#  680: 'outfit',
#  681: 'flight',
#  682: 'graffiti',
#  683: 'carriage',
#  684: 'working',
#  685: 'meal',
#  686: 'tusk',
#  687: 'seen',
#  688: 'wrist',
#  689: 'lap',
#  690: 'suv',
#  691: 'doors',
#  692: 'bull',
#  693: 'taxi',
#  694: 'tea',
#  695: 'decorative',
#  696: 'fan',
#  697: 'deep',
#  698: 'ears',
#  699: 'bush',
#  700: 'walk',
#  701: 'leather',
#  702: 'lawn',
#  703: 'fashioned',
#  704: 'windshield',
#  705: 'smoke',
#  706: 'worn',
#  707: 'meat',
#  708: 'closed',
#  709: 'ice',
#  710: 'liquid',
#  711: 'birthday',
#  712: 'slices',
#  713: 'tabby',
#  714: 'tongue',
#  715: 'preparing',
#  716: 'french',
#  717: 'intersection',
#  718: 'rain',
#  719: 'skirt',
#  720: 'banner',
#  721: 'traveling',
#  722: 'match',
#  723: 'tiled',
#  724: 'yard',
#  725: 'clocks',
#  726: 'opened',
#  727: 'neon',
#  728: 'enclosure',
#  729: 'stacked',
#  730: 'eyeglasses',
#  731: 'towels',
#  732: 'jar',
#  733: 'skies',
#  734: 'setting',
#  735: 'vases',
#  736: 'brushing',
#  737: 'fries',
#  738: 'surfers',
#  739: 'carpet',
#  740: 'eaten',
#  741: 'lots',
#  742: 'poles',
#  743: 'pasture',
#  744: 'blond',
#  745: 'brush',
#  746: 'catching',
#  747: 'here',
#  748: 'vegetable',
#  749: 'furry',
#  750: 'six',
#  751: 'showing',
#  752: 'huge',
#  753: 'office',
#  754: 'upside',
#  755: 'broken',
#  756: 'rack',
#  757: 'scarf',
#  758: 'stairs',
#  759: 'outdoor',
#  760: 'tip',
#  761: 'hood',
#  762: 'log',
#  763: 'stick',
#  764: 'mounted',
#  765: 'spots',
#  766: 'curly',
#  767: 'resting',
#  768: 'kitten',
#  769: 'shore',
#  770: 'chicken',
#  771: 'ripe',
#  772: 'racquet',
#  773: 'guys',
#  774: 'toddler',
#  775: 'gate',
#  776: 'vehicles',
#  777: 'cab',
#  778: 'duck',
#  779: 'tub',
#  780: 'dining',
#  781: 'rectangular',
#  782: 'wagon',
#  783: 'circular',
#  784: 'place',
#  785: 'having',
#  786: 'headlight',
#  787: 'family',
#  788: 'collar',
#  789: 'bucket',
#  790: 'pepper',
#  791: 'cooking',
#  792: 'roman',
#  793: 'catcher',
#  794: 'bottles',
#  795: 'gloves',
#  796: 'lift',
#  797: 'egg',
#  798: 'panda',
#  799: 'floral',
#  800: 'monkey',
#  801: 'fresh',
#  802: 'candles',
#  803: 'toppings',
#  804: 'delicious',
#  805: 'drink',
#  806: 'cardboard',
#  807: 'items',
#  808: 'pictures',
#  809: 'rear',
#  810: 'band',
#  811: 'telephone',
#  812: 'paved',
#  813: 'machine',
#  814: 'holder',
#  815: 'cord',
#  816: 'walls',
#  817: 'interior',
#  818: 'curved',
#  819: 'church',
#  820: 'growing',
#  821: 'commercial',
#  822: 'dinner',
#  823: 'blurry',
#  824: 'sit',
#  825: 'vintage',
#  826: 'branches',
#  827: 'net',
#  828: 'apron',
#  829: 'fighter',
#  830: 'electric',
#  831: 'play',
#  832: 'leash',
#  833: 'high',
#  834: 'path',
#  835: 'rider',
#  836: 'used',
#  837: 'sandwiches',
#  838: 'crust',
#  839: 'happy',
#  840: 'tent',
#  841: 'partially',
#  842: 'boots',
#  843: 'glowing',
#  844: 'thick',
#  845: 'dock',
#  846: 'scooter',
#  847: 'poster',
#  848: 'bar',
#  849: 'block',
#  850: 'trim',
#  851: 'panel',
#  852: 'napkin',
#  853: 'wetsuit',
#  854: 'airplanes',
#  855: 'military',
#  856: 'floating',
#  857: 'puppy',
#  858: 'garbage',
#  859: 'sheet',
#  860: 'antique',
#  861: 'grill',
#  862: 'clothing',
#  863: 'subway',
#  864: 'platter',
#  865: 'cabinets',
#  866: 'race',
#  867: 'iron',
#  868: 'ring',
#  869: 'umpire',
#  870: 'as',
#  871: 'text',
#  872: 'bending',
#  873: 'tiny',
#  874: 'asphalt',
#  875: 'hotdog',
#  876: 'surfboards',
#  877: 'clothes',
#  878: 'rolling',
#  879: 'flags',
#  880: 'salad',
#  881: 'breakfast',
#  882: 'books',
#  883: 'pepperoni',
#  884: 'have',
#  885: 'boarding',
#  886: 'swimming',
#  887: 'busy',
#  888: 'decorated',
#  889: 'restroom',
#  890: 'kneeling',
#  891: 'steps',
#  892: 'horn',
#  893: 'rope',
#  894: 'bare',
#  895: 'shape',
#  896: 'clay',
#  897: 'glazed',
#  898: 'label',
#  899: 'ship',
#  900: 'soda',
#  901: 'mostly',
#  902: 'pie',
#  903: 'necklace',
#  904: 'bags',
#  905: 'frosting',
#  906: 'link',
#  907: 'while',
#  908: 'plain',
#  909: 'they',
#  910: 'wings',
#  911: 'goat',
#  912: 'sprinkles',
#  913: 'skater',
#  914: 'single',
#  915: 'hitting',
#  916: 'urinal',
#  917: 'railway',
#  918: 'dessert',
#  919: 'rice',
#  920: 'landing',
#  921: 'do',
#  922: 'plants',
#  923: 'parrot',
#  924: 'highway',
#  925: 'paddle',
#  926: 'trail',
#  927: 'juice',
#  928: 'rainbow',
#  929: 'slat',
#  930: 'entrance',
#  931: 'work',
#  932: 'kettle',
#  933: 'balcony',
#  934: 'forefront',
#  935: 'stopped',
#  936: 'shot',
#  937: 'patio',
#  938: 'shop',
#  939: 'stool',
#  940: 'shaker',
#  941: 'icing',
#  942: 'falling',
#  943: 'hay',
#  944: 'dead',
#  945: 'winter',
#  946: 'lunch',
#  947: 'socks',
#  948: 'control',
#  949: 'headlights',
#  950: 'propeller',
#  951: 'bent',
#  952: 'be',
#  953: 'dot',
#  954: 'touching',
#  955: 'country',
#  956: 'rocky',
#  957: 'mini',
#  958: 'bow',
#  959: 'rusted',
#  960: 'checkered',
#  961: 'tomatoes',
#  962: 'suitcases',
#  963: 'mound',
#  964: 'baked',
#  965: 'power',
#  966: 'cattle',
#  967: 'lighthouse',
#  968: 'wind',
#  969: 'countertop',
#  970: 'perched',
#  971: 'rusty',
#  972: 'figure',
#  973: 'pocket',
#  974: 'sleeve',
#  975: 'star',
#  976: 'who',
#  977: 'colour',
#  978: 'mark',
#  979: 'stroller',
#  980: 'horizon',
#  981: 'medium',
#  982: 'cage',
#  983: 'butter',
#  984: 'sill',
#  985: 'multicolored',
#  986: 'art',
#  987: 'bushes',
#  988: 'ornate',
#  989: 'walkway',
#  990: 'terminal',
#  991: 'fireplace',
#  992: 'candle',
#  993: 'stuff',
#  994: 'aircraft',
#  995: 'hard',
#  996: 'trolley',
#  997: 'meters',
#  998: 'key',
#  999: 'midair',
#  1000: 'pulled',
#  ...}

# %%
reverse_source_word_index=x_tokens.index_word
len(reverse_source_word_index)
# Out:
# 5546

# %%
target_word_index=y_tokens.word_index
len(target_word_index)
# Out:
# 8720

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=[encoder_inputs,img_inputs],outputs=[encoder_outputs, state_h, state_c])
encoder_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 25)]                 0         []
#
#  embedding (Embedding)       (None, 25, 512)              2840064   ['input_1[0][0]']
#
#  input_2 (InputLayer)        [(None, 4096)]               0         []
#
#  lstm (LSTM)                 [(None, 25, 512),            2099200   ['embedding[0][0]']
#                               (None, 512),
#                               (None, 512)]
#
#  dense (Dense)               (None, 512)                  2097664   ['input_2[0][0]']
#
#  lstm_1 (LSTM)               [(None, 25, 512),            2099200   ['lstm[0][0]']
#                               (None, 512),
#                               (None, 512)]
#
#  repeat_vector (RepeatVecto  (None, 25, 512)              0         ['dense[0][0]']
#  r)
#
#  concatenate (Concatenate)   (None, 25, 1024)             0         ['lstm_1[0][0]',
#                                                                      'repeat_vector[0][0]']
#
#  lstm_2 (LSTM)               [(None, 25, 512),            3147776   ['concatenate[0][0]']
#                               (None, 512),
#                               (None, 512)]
#
# ==================================================================================================
# Total params: 12283904 (46.86 MB)
# Trainable params: 12283904 (46.86 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    encoder_model,
    to_file='model.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB'
)

# %%
# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
encoder_inf_states=Input(shape=(trmaxlen_english,512,))
decoder_hidden_state_input = Input(shape=(trmaxlen_english,latent_dim))
print(decoder_inputs.get_shape)
#print(dec_emb.get_shape)
# Out:
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, None) dtype=float32 (created by layer 'input_3')>>

# %%
# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs)
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])
attn_inf_out, attn_inf_states = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_inf_out])
# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat)

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])
decoder_model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, None)]               0         []
#
#  embedding_1 (Embedding)     (None, None, 512)            4465152   ['input_3[0][0]']
#
#  input_4 (InputLayer)        [(None, 512)]                0         []
#
#  input_5 (InputLayer)        [(None, 512)]                0         []
#
#  lstm_3 (LSTM)               [(None, None, 512),          2099200   ['embedding_1[1][0]',
#                               (None, 512),                           'input_4[0][0]',
#                               (None, 512)]                           'input_5[0][0]']
#
#  input_7 (InputLayer)        [(None, 25, 512)]            0         []
#
#  attention_layer (Attention  ((None, None, 512),          524800    ['input_7[0][0]',
#  Layer)                       (None, None, 25))                      'lstm_3[1][0]']
#
#  concat (Concatenate)        (None, None, 1024)           0         ['lstm_3[1][0]',
#                                                                      'attention_layer[1][0]']
#
#  time_distributed (TimeDist  (None, None, 8721)           8939025   ['concat[0][0]']
#  ributed)
#
# ==================================================================================================
# Total params: 16028177 (61.14 MB)
# Trainable params: 16028177 (61.14 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    decoder_model,
    to_file='model.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB'
)

# %%
def decode_sequence(input_seq,img):
    img=img[np.newaxis,:]
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict([input_seq, img])

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))

    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sos']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]

        if(sampled_token!='eos'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eos'  or len(decoded_sentence.split()) >= (trmaxlen_malayalam -1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sos']) and i!=target_word_index['eos']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
seq2summary(x_tr[1])
# Out:
# 'అబ్బాయి పైభాగంతో పెయింటింగ్ ఒక '

# %%
ttvgg_feature=np.load('/content/drive/My Drive/testfeature.npy', encoding='bytes')

# %%
for i in range(5):
    print("Review:",seq2text(x_tt[i]))
    print("Original summary:",seq2summary(y_tt[i]))
    print("Predicted summary:",decode_sequence(x_tt[i].reshape(1,trmaxlen_english),ttvgg_feature[i]))
    print("\n")

# %%
#error due to probelm in test data
for i in range(10):
    print("Review:",seq2text(x_tt[i]))
    print("Original summary:",seq2summary(y_tt[i]))
    print("Predicted summary:",decode_sequence(x_tt[i].reshape(1,trmaxlen_english),ttvgg_feature[i]))
    print("\n")
# Out:
# Review: the orange traffic cone
# Original summary: నారింజ రంగు ట్రాఫిక్ కోన్
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# Predicted summary:  చెట్టు ముక్కలు చేయబడింది
#
#
# Review: a stop light
# Original summary: ఒక స్టాప్ లైట్
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  ఒక ట్రాఫిక్ లైట్
#
#
# Review: three zebras in the wild
# Original summary: అడవిలో మూడు జీబ్రాలు
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# Predicted summary:  అడవిలో మూడు జీబ్రాలు
#
#
# Review: cars parked along the side of the road
# Original summary: రోడ్డు పక్కన పార్క్ చేసిన కార్లు
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  రోడ్డు పక్కన కార్లు ఆగి ఉన్నాయి
#
#
# Review: a man climbing into a train
# Original summary: ఒక వ్యక్తి
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  ఒక వ్యక్తి మోటారుసైకిల్‌ను పట్టుకొని ఉన్నాడు
#
#
# Review: this is a person
# Original summary: ఇది ఒక వ్యక్తి
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  ఇది ఒక వ్యక్తి
#
#
# Review: box of small oranges in a box
# Original summary: ఒక పెట్టెలో చిన్న నారింజల పెట్టె
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# Predicted summary:  పెట్టెలో ఒక చిన్న నారింజ పండు
#
#
# Review: signs about on a post
# Original summary: పోస్ట్‌లో గురించి సంకేతాలు
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  ఒక స్తంభంపై వీధి గుర్తు
#
#
# Review: a white box filled with doughnuts
# Original summary: డోనట్స్‌తో నిండిన తెల్లటి పెట్టె
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  కేక్ పైన తెల్లటి ముక్క
#
#
# Review: person wearing a black hat
# Original summary: నల్ల టోపీ ధరించిన వ్యక్తి
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  నల్ల హెల్మెట్ ధరించిన వ్యక్తి

# %%
# !pip install sacrebleu
import sacrebleu
import random

# %%
temp_o=[]
temp_p=[]
for i in range(1000):
    s=random.randint(0,len(y_tt)-1)
    temp_o.append(seq2summary(y_tt[s]))
    temp_p.append(decode_sequence(x_tt[s].reshape(1,trmaxlen_english),ttvgg_feature[s]))
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# ...
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step

# %%
bleu = sacrebleu.corpus_bleu(temp_o, [temp_p],lowercase=True, tokenize='intl')
print(bleu.score)
# Out:
# 23.449216652831044
